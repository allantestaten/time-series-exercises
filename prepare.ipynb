# %%
import pandas as pd
from datetime import timedelta, datetime
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import statsmodels.api as sm
from env import get_db_url
import os
from acquire import wrangle_store_data
import warnings
import seaborn as sns
import requests





warnings.filterwarnings("ignore")

# plotting defaults
plt.rc('figure', figsize=(13, 7))
plt.style.use('seaborn-whitegrid')
plt.rc('font', size=16)

# %% [markdown]
# # Exercises
# The end result of this exercise should be a file named `prepare.py`.
#
# **Using your store items data:**
#
# - Convert date column to datetime format.
# - Plot the distribution of sale_amount and item_price.
# - Set the index to be the datetime variable.
# - Add a 'month' and 'day of week' column to your dataframe.
# - Add a column to your dataframe, sales_total, which is a derived from sale_amount (total items) and item_price.
# - Make sure all the work that you have done above is reproducible. That is, you should put the code above into separate functions and be able to re-run the functions and get the same results.
#
# **Using OPS data (hint: if you don't know how to acquire this data, do a bit of google searching on how to do this with pandas):**
# - Acquire the Open Power Systems Data for Germany, which has been rapidly expanding its renewable energy production in recent years. The data set includes country-wide totals of electricity consumption, wind power production, and solar power production for 2006-2017. You can get the data here: https://raw.githubusercontent.com/jenfly/opsd/master/opsd_germany_daily.csv
# - Convert date column to datetime format.
# - Plot the distribution of each of your variables.
# - Set the index to be the datetime variable.
# - Add a month and a year column to your dataframe.
# - Fill any missing values.
# - Make sure all the work that you have done above is reproducible. That is, you should put the code above into separate functions and be able to re-run the functions and get the same results.

# %%
# acquire data 
df = wrangle_store_data()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 913000 entries, 0 to 912999
# Data columns (total 14 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   store_id       913000 non-null  int64
#  1   item_id        913000 non-null  int64
#  2   item_upc14     913000 non-null  int64
#  3   item_upc12     913000 non-null  int64
#  4   item_brand     913000 non-null  object
#  5   item_name      913000 non-null  object
#  6   item_price     913000 non-null  float64
#  7   sale_id        913000 non-null  int64
#  8   sale_date      913000 non-null  object
#  9   sale_amount    913000 non-null  int64
#  10  store_address  913000 non-null  object
#  11  store_zipcode  913000 non-null  int64
#  12  store_city     913000 non-null  object
#  13  store_state    913000 non-null  object
# dtypes: float64(1), int64(7), object(6)
# memory usage: 97.5+ MB

# %%
df.head()
# Out:
#    store_id  item_id   item_upc14   item_upc12 item_brand  \
# 0         1        1  35200264013  35200264013   Riceland
# 1         1        1  35200264013  35200264013   Riceland
# 2         1        1  35200264013  35200264013   Riceland
# 3         1        1  35200264013  35200264013   Riceland
# 4         1        1  35200264013  35200264013   Riceland
#
#                         item_name  item_price  sale_id   sale_date  \
# 0  Riceland American Jazmine Rice        0.84        1  2013-01-01
# 1  Riceland American Jazmine Rice        0.84        2  2013-01-02
# 2  Riceland American Jazmine Rice        0.84        3  2013-01-03
# 3  Riceland American Jazmine Rice        0.84        4  2013-01-04
# 4  Riceland American Jazmine Rice        0.84        5  2013-01-05
#
#    sale_amount           store_address  store_zipcode   store_city store_state
# 0           13  12125 Alamo Ranch Pkwy          78253  San Antonio          TX
# 1           11  12125 Alamo Ranch Pkwy          78253  San Antonio          TX
# 2           14  12125 Alamo Ranch Pkwy          78253  San Antonio          TX
# 3           13  12125 Alamo Ranch Pkwy          78253  San Antonio          TX
# 4           10  12125 Alamo Ranch Pkwy          78253  San Antonio          TX

# %% [markdown]
# ## Convert date column to datetime format.

# %%
# convert our date column to datetime type
df.sale_date = pd.to_datetime(df.sale_date)

# %%
def date_time_conversion(df,date_column):
    # convert our date column to datetime type
    df[date_column] = pd.to_datetime(df[date_column])
    return df

# %% [markdown]
# ## Plot the distribution of sale_amount and item_price.

# %%
sns.scatterplot(data=df, x='item_price', y='sale_amount')
# Out:
# <AxesSubplot:xlabel='item_price', ylabel='sale_amount'>

# %% [markdown]
# ## Set the index to be the datetime variable.

# %%
# Set the index as that date and then sort index (by the date)
df = df.set_index("sale_date").sort_index()

# %% [markdown]
# ## Add a 'month' and 'day of week' column to your dataframe.

# %%
    # Set the index as that date and then sort index (by the date)
    df = df.set_index("sale_date").sort_index()
    # adding month column to dataframe(date is in index so must use df.index)
    df['month'] = df.index.month
    # adding day of week to dataframe (date is in index so must use df.index)
    df['day'] = df.index.day_name()
# Out:
#             store_id  item_id    item_upc14    item_upc12          item_brand  \
# sale_date
# 2013-01-01         1        1   35200264013   35200264013            Riceland
# 2013-01-01         3       17   88313590791   88313590791               Ducal
# 2013-01-01        10        7   70177154004   70177154004  Twinings Of London
# 2013-01-01         3       18   21200725340   21200725340              Scotch
# 2013-01-01         3       19   41520035646   41520035646             Careone
# ...              ...      ...           ...           ...                 ...
# 2017-12-31         7       39   28400029254   28400029254            Munchies
# 2017-12-31         7       40   42272008063   42272008063                Amys
# 2017-12-31         7       41   31000670016   31000670016         P.f. Changs
# 2017-12-31         7       28  719175900007  719175900007        Usda Produce
# 2017-12-31        10       50   47445919221   47445919221              Choice
#
#                                                     item_name  item_price  \
# sale_date
# 2013-01-01                     Riceland American Jazmine Rice        0.84
# 2013-01-01                            Ducal Refried Red Beans        1.16
# 2013-01-01  Twinings Of London Classics Lady Grey Tea - 20 Ct        9.64
# 2013-01-01    Scotch Removable Clear Mounting Squares - 35 Ct        4.39
# 2013-01-01                     Careone Family Comb Set - 8 Ct        0.74
# ...                                                       ...         ...
# 2017-12-31  Munchies Sandwich Crackers Cheddar Cheese On G...        9.02
# 2017-12-31               Amys Light & Lean Spaghetti Italiano        0.60
# 2017-12-31  P.f. Changs Home Menu Meal For Two Beef With B...        5.62
# 2017-12-31                                              Guava        7.52
# 2017-12-31  Choice Organic Teas Black Tea Classic Black - ...        5.20
#
#             sale_id  sale_amount            store_address  store_zipcode  \
# sale_date
# 2013-01-01        1           13   12125 Alamo Ranch Pkwy          78253
# 2013-01-01   295813           26  2118 Fredericksburg Rdj          78201
# 2013-01-01   125995           32     8503 NW Military Hwy          78231
# 2013-01-01   314073           45  2118 Fredericksburg Rdj          78201
# 2013-01-01   332333           34  2118 Fredericksburg Rdj          78201
# ...             ...          ...                      ...            ...
# 2017-12-31   706662           31   12018 Perrin Beitel Rd          78217
# 2017-12-31   724922           22   12018 Perrin Beitel Rd          78217
# 2017-12-31   743182           19   12018 Perrin Beitel Rd          78217
# 2017-12-31   505802           59   12018 Perrin Beitel Rd          78217
# 2017-12-31   913000           82     8503 NW Military Hwy          78231
#
#              store_city store_state  month      day  sales_total
# sale_date
# 2013-01-01  San Antonio          TX      1  Tuesday        10.92
# 2013-01-01  San Antonio          TX      1  Tuesday        30.16
# 2013-01-01  San Antonio          TX      1  Tuesday       308.48
# 2013-01-01  San Antonio          TX      1  Tuesday       197.55
# 2013-01-01  San Antonio          TX      1  Tuesday        25.16
# ...                 ...         ...    ...      ...          ...
# 2017-12-31  San Antonio          TX     12   Sunday       279.62
# 2017-12-31  San Antonio          TX     12   Sunday        13.20
# 2017-12-31  San Antonio          TX     12   Sunday       106.78
# 2017-12-31  San Antonio          TX     12   Sunday       443.68
# 2017-12-31  San Antonio          TX     12   Sunday       426.40
#
# [913000 rows x 16 columns]

# %%
def add_month_day(df,date_column):
    '''this function will set the index to the dat column and add a month and day column'''
    
    # adding month column to dataframe(date is in index so must use df.index)
    df['month'] = df.index.month
    # adding day of week to dataframe (date is in index so must use df.index)
    df['day'] = df.index.day_name()

# %% [markdown]
# ## Add a column to your dataframe, sales_total, which is a derived from sale_amount (total items) and item_price.

# %%
# add sales_total column 
df['sales_total'] = df['sale_amount']*df['item_price']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /opt/homebrew/anaconda3/lib/python3.9/site-packages/pandas/core/indexes/base.py:3621, in Index.get_loc(self, key, method, tolerance)
#    3620 try:
# -> 3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
#
# File /opt/homebrew/anaconda3/lib/python3.9/site-packages/pandas/_libs/index.pyx:136, in pandas._libs.index.IndexEngine.get_loc()
#
# File /opt/homebrew/anaconda3/lib/python3.9/site-packages/pandas/_libs/index.pyx:163, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:5198, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:5206, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'sale_amount'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Input In [92], in <cell line: 2>()
#       1 # add sales_total column
# ----> 2 df['sales_total'] = df['sale_amount']*df['item_price']
#
# File /opt/homebrew/anaconda3/lib/python3.9/site-packages/pandas/core/frame.py:3505, in DataFrame.__getitem__(self, key)
#    3503 if self.columns.nlevels > 1:
#    3504     return self._getitem_multilevel(key)
# -> 3505 indexer = self.columns.get_loc(key)
#    3506 if is_integer(indexer):
#    3507     indexer = [indexer]
#
# File /opt/homebrew/anaconda3/lib/python3.9/site-packages/pandas/core/indexes/base.py:3623, in Index.get_loc(self, key, method, tolerance)
#    3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
# -> 3623     raise KeyError(key) from err
#    3624 except TypeError:
#    3625     # If we have a listlike key, _check_indexing_error will raise
#    3626     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3627     #  the TypeError.
#    3628     self._check_indexing_error(key)
#
# KeyError: 'sale_amount'

# %%
def sales_total(df,sum_total_column,x,y):
    '''this function will create a sum from two columns'''
    # calculate total sales_total column 
    df['sum_total_column'] = df[x]*df[y]

# %%
sales_total(df,'sum_total','sale_amount','item_price')

df
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /opt/homebrew/anaconda3/lib/python3.9/site-packages/pandas/core/indexes/base.py:3621, in Index.get_loc(self, key, method, tolerance)
#    3620 try:
# -> 3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
#
# File /opt/homebrew/anaconda3/lib/python3.9/site-packages/pandas/_libs/index.pyx:136, in pandas._libs.index.IndexEngine.get_loc()
#
# File /opt/homebrew/anaconda3/lib/python3.9/site-packages/pandas/_libs/index.pyx:163, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:5198, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:5206, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'sale_amount'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Input In [94], in <cell line: 1>()
# ----> 1 sales_total(df,'sum_total','sale_amount','item_price')
#       3 df
#
# Input In [93], in sales_total(df, sum_total_column, x, y)
#       2 '''this function will create a sum from two columns'''
#       3 # calculate total sales_total column
# ----> 4 df['sum_total_column'] = df[x]*df[y]
#
# File /opt/homebrew/anaconda3/lib/python3.9/site-packages/pandas/core/frame.py:3505, in DataFrame.__getitem__(self, key)
#    3503 if self.columns.nlevels > 1:
#    3504     return self._getitem_multilevel(key)
# -> 3505 indexer = self.columns.get_loc(key)
#    3506 if is_integer(indexer):
#    3507     indexer = [indexer]
#
# File /opt/homebrew/anaconda3/lib/python3.9/site-packages/pandas/core/indexes/base.py:3623, in Index.get_loc(self, key, method, tolerance)
#    3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
# -> 3623     raise KeyError(key) from err
#    3624 except TypeError:
#    3625     # If we have a listlike key, _check_indexing_error will raise
#    3626     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3627     #  the TypeError.
#    3628     self._check_indexing_error(key)
#
# KeyError: 'sale_amount'

# %% [markdown]
# ## Make sure all the work that you have done above is reproducible. That is, you should put the code above into separate functions and be able to re-run the functions and get the same results.

# %% [markdown]
# **Using OPS data (hint: if you don't know how to acquire this data, do a bit of google searching on how to do this with pandas):**
# - Acquire the Open Power Systems Data for Germany, which has been rapidly expanding its renewable energy production in recent years. The data set includes country-wide totals of electricity consumption, wind power production, and solar power production for 2006-2017. You can get the data here: https://raw.githubusercontent.com/jenfly/opsd/master/opsd_germany_daily.csv
# - Convert date column to datetime format.
# - Plot the distribution of each of your variables.
# - Set the index to be the datetime variable.
# - Add a month and a year column to your dataframe.
# - Fill any missing values.
# - Make sure all the work that you have done above is reproducible. That is, you should put the code above into separate functions and be able to re-run the functions and get the same results.

# %% [markdown]
# ## - Acquire the Open Power Systems Data for Germany, which has been rapidly expanding its renewable energy production in recent years. The data set includes country-wide totals of electricity consumption, wind power production, and solar power production for 2006-2017. You can get the data here: https://raw.githubusercontent.com/jenfly/opsd/master/opsd_germany_daily.csv

# %%
# acquire data 
df = pd.read_csv('opsd_germany_daily.csv')

df
# Out:
#             Date  Consumption     Wind   Solar  Wind+Solar
# 0     2006-01-01   1069.18400      NaN     NaN         NaN
# 1     2006-01-02   1380.52100      NaN     NaN         NaN
# 2     2006-01-03   1442.53300      NaN     NaN         NaN
# 3     2006-01-04   1457.21700      NaN     NaN         NaN
# 4     2006-01-05   1477.13100      NaN     NaN         NaN
# ...          ...          ...      ...     ...         ...
# 4378  2017-12-27   1263.94091  394.507  16.530     411.037
# 4379  2017-12-28   1299.86398  506.424  14.162     520.586
# 4380  2017-12-29   1295.08753  584.277  29.854     614.131
# 4381  2017-12-30   1215.44897  721.247   7.467     728.714
# 4382  2017-12-31   1107.11488  721.176  19.980     741.156
#
# [4383 rows x 5 columns]

# %% [markdown]
# ##  Convert date column to datetime format.

# %%
# Convert date column to datetime format.
date_time_conversion(df,'Date')
# Out:
#            Date  Consumption     Wind   Solar  Wind+Solar
# 0    2006-01-01   1069.18400      NaN     NaN         NaN
# 1    2006-01-02   1380.52100      NaN     NaN         NaN
# 2    2006-01-03   1442.53300      NaN     NaN         NaN
# 3    2006-01-04   1457.21700      NaN     NaN         NaN
# 4    2006-01-05   1477.13100      NaN     NaN         NaN
# ...         ...          ...      ...     ...         ...
# 4378 2017-12-27   1263.94091  394.507  16.530     411.037
# 4379 2017-12-28   1299.86398  506.424  14.162     520.586
# 4380 2017-12-29   1295.08753  584.277  29.854     614.131
# 4381 2017-12-30   1215.44897  721.247   7.467     728.714
# 4382 2017-12-31   1107.11488  721.176  19.980     741.156
#
# [4383 rows x 5 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4383 entries, 0 to 4382
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Date         4383 non-null   datetime64[ns]
#  1   Consumption  4383 non-null   float64
#  2   Wind         2920 non-null   float64
#  3   Solar        2188 non-null   float64
#  4   Wind+Solar   2187 non-null   float64
# dtypes: datetime64[ns](1), float64(4)
# memory usage: 171.3 KB

# %% [markdown]
# ## Plot the distribution of each of your variables.

# %%
# Plot the distribution of each of your variables.
df.hist()
# Out:
# array([[<AxesSubplot:title={'center':'Date'}>,
#         <AxesSubplot:title={'center':'Consumption'}>],
#        [<AxesSubplot:title={'center':'Wind'}>,
#         <AxesSubplot:title={'center':'Solar'}>],
#        [<AxesSubplot:title={'center':'Wind+Solar'}>, <AxesSubplot:>]],
#       dtype=object)

# %% [markdown]
# ##  Set the index to be the datetime variable.

# %%
#Set the index to be the datetime variable.

# Set the index as that date and then sort index (by the date)
df = df.set_index("Date").sort_index()

# %% [markdown]
# ## Add a month and a year column to your dataframe.

# %%
# adding year column to dataframe(date is in index so must use df.index)
df['year'] = df.index.year
# adding month of week to dataframe (date is in index so must use df.index)
df['month'] = df.index.month

# %% [markdown]
# ## Fill any missing values.

# %%
df
# Out:
#             Consumption     Wind   Solar  Wind+Solar  year  month
# Date
# 2006-01-01   1069.18400      NaN     NaN         NaN  2006      1
# 2006-01-02   1380.52100      NaN     NaN         NaN  2006      1
# 2006-01-03   1442.53300      NaN     NaN         NaN  2006      1
# 2006-01-04   1457.21700      NaN     NaN         NaN  2006      1
# 2006-01-05   1477.13100      NaN     NaN         NaN  2006      1
# ...                 ...      ...     ...         ...   ...    ...
# 2017-12-27   1263.94091  394.507  16.530     411.037  2017     12
# 2017-12-28   1299.86398  506.424  14.162     520.586  2017     12
# 2017-12-29   1295.08753  584.277  29.854     614.131  2017     12
# 2017-12-30   1215.44897  721.247   7.467     728.714  2017     12
# 2017-12-31   1107.11488  721.176  19.980     741.156  2017     12
#
# [4383 rows x 6 columns]

# %% [markdown]
# ## Make sure all the work that you have done above is reproducible. That is, you should put the code above into separate functions and be able to re-run the functions and get the same results.
